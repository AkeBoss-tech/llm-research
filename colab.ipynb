# %%
# Install Rust (needed to compile your custom tokenizer)
# !curl --proto '=https' --tlsv1.2 -sSf https://sh.rustup.rs | sh -s -- -y
import os
os.environ['PATH'] += ":/root/.cargo/bin"

# Install build tool
# !pip install maturin

# !git clone https://github.com/AkeBoss-tech/llm-research

# Enter the directory
# %cd llm-research
# !pip install -e .

# !python eval_gsm8k_all_models.py \
    # --models d32 \
#     --max-problems 1000 \
#     --dtype float32 \
#     --output-dir /content/results

from google.colab import drive
drive.mount('/content/drive')

# !python eval_gsm8k_all_models.py \
    --models d32 \
    --max-problems 1000 \
    --dtype float32 \
    --output-dir /content/drive/MyDrive/llm_results
